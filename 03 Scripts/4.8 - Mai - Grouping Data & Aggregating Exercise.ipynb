# %% [markdown]
# # Contents
# ### Find the aggregated mean of the “order_number” column grouped by “department_id”
# ### Difference between the spending habits of the three types of customers (whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers
# ### Create a spending flag for each user based on the average price across all their orders
# ### Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import Data
path = r'/Users/maitran/Documents/Instacart Basket Analysis'

# %%
# Import the orders_products_merge dataframe
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_2.pkl'))

# %% [markdown]
# ### Find the aggregated mean of the “order_number” column grouped by “department_id”

# %%
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# #### Observation: The mean in each department of the whole data set is totally different than the mean of the subset. The subset only contain 1 mil rows which leading to not showing all the results for all the departments.

# %% [markdown]
# ### Creating a loyalty flag for existing customers using the transform() and loc() functions

# %%
#Create another new column that assigns a loyalty flag to each customer according to the criteria
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
#
#     reordered  ...  product_name aisle_id  department_id  prices  _merge  \
# 0           0  ...          Soda       77              7     9.0    both
# 1           1  ...          Soda       77              7     9.0    both
# 2           1  ...          Soda       77              7     9.0    both
# 3           1  ...          Soda       77              7     9.0    both
# 4           1  ...          Soda       77              7     9.0    both
# 5           1  ...          Soda       77              7     9.0    both
# 6           1  ...          Soda       77              7     9.0    both
# 7           1  ...          Soda       77              7     9.0    both
# 8           1  ...          Soda       77              7     9.0    both
# 9           1  ...          Soda       77              7     9.0    both
# 10          0  ...          Soda       77              7     9.0    both
# 11          1  ...          Soda       77              7     9.0    both
# 12          1  ...          Soda       77              7     9.0    both
# 13          1  ...          Soda       77              7     9.0    both
# 14          1  ...          Soda       77              7     9.0    both
#
#        busiest_day    busiest_days busiest_period_of_day    price_range_loc  \
# 0   Regularly busy  Regularly days        Average orders  Mid-range product
# 1   Regularly busy    Slowest days        Average orders  Mid-range product
# 2   Regularly busy    Slowest days           Most orders  Mid-range product
# 3       Least busy    Slowest days        Average orders  Mid-range product
# 4       Least busy    Slowest days           Most orders  Mid-range product
# 5   Regularly busy  Regularly days        Average orders  Mid-range product
# 6   Regularly busy    Busiest days           Most orders  Mid-range product
# 7   Regularly busy    Busiest days           Most orders  Mid-range product
# 8   Regularly busy    Busiest days           Most orders  Mid-range product
# 9       Least busy    Slowest days        Average orders  Mid-range product
# 10  Regularly busy    Busiest days           Most orders  Mid-range product
# 11  Regularly busy  Regularly days           Most orders  Mid-range product
# 12  Regularly busy  Regularly days           Most orders  Mid-range product
# 13  Regularly busy    Busiest days           Most orders  Mid-range product
# 14  Regularly busy    Busiest days           Most orders  Mid-range product
#
#    max_order
# 0         10
# 1         10
# 2         10
# 3         10
# 4         10
# 5         10
# 6         10
# 7         10
# 8         10
# 9         10
# 10        22
# 11        22
# 12        22
# 13        22
# 14        22
#
# [15 rows x 21 columns]

# %%
## Deriving Columns with loc()
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Check output
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# ### Difference between the spending habits of the three types of customers (whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.)

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']})
# Out:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0  106814042.2
# New customer      13.294670  1.0  99999.0   83011787.2
# Regular customer  12.495717  1.0  99999.0  198391693.2

# %% [markdown]
# #### Observation: There is no difference among three types of customers in min and max spending. However, new customers tend to spend more compared to regular and loyal customers. New customer spending avarage is 13.2 while regular customer is 12.4 and loyal customer is 10.3.

# %% [markdown]
# ### Create a spending flag for each user based on the average price across all their orders

# %%
# Creating “average_price” column using transform()
ords_prods_merge['avg_order'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
#
#     reordered  ...  department_id prices  _merge     busiest_day  \
# 0           0  ...              7    9.0    both  Regularly busy
# 1           1  ...              7    9.0    both  Regularly busy
# 2           1  ...              7    9.0    both  Regularly busy
# 3           1  ...              7    9.0    both      Least busy
# 4           1  ...              7    9.0    both      Least busy
# 5           1  ...              7    9.0    both  Regularly busy
# 6           1  ...              7    9.0    both  Regularly busy
# 7           1  ...              7    9.0    both  Regularly busy
# 8           1  ...              7    9.0    both  Regularly busy
# 9           1  ...              7    9.0    both      Least busy
# 10          0  ...              7    9.0    both  Regularly busy
# 11          1  ...              7    9.0    both  Regularly busy
# 12          1  ...              7    9.0    both  Regularly busy
# 13          1  ...              7    9.0    both  Regularly busy
# 14          1  ...              7    9.0    both  Regularly busy
#
#       busiest_days busiest_period_of_day    price_range_loc max_order  \
# 0   Regularly days        Average orders  Mid-range product        10
# 1     Slowest days        Average orders  Mid-range product        10
# 2     Slowest days           Most orders  Mid-range product        10
# 3     Slowest days        Average orders  Mid-range product        10
# 4     Slowest days           Most orders  Mid-range product        10
# 5   Regularly days        Average orders  Mid-range product        10
# 6     Busiest days           Most orders  Mid-range product        10
# 7     Busiest days           Most orders  Mid-range product        10
# 8     Busiest days           Most orders  Mid-range product        10
# 9     Slowest days        Average orders  Mid-range product        10
# 10    Busiest days           Most orders  Mid-range product        22
# 11  Regularly days           Most orders  Mid-range product        22
# 12  Regularly days           Most orders  Mid-range product        22
# 13    Busiest days           Most orders  Mid-range product        22
# 14    Busiest days           Most orders  Mid-range product        22
#
#         loyalty_flag avg_order
# 0       New customer  6.367797
# 1       New customer  6.367797
# 2       New customer  6.367797
# 3       New customer  6.367797
# 4       New customer  6.367797
# 5       New customer  6.367797
# 6       New customer  6.367797
# 7       New customer  6.367797
# 8       New customer  6.367797
# 9       New customer  6.367797
# 10  Regular customer  3.980556
# 11  Regular customer  3.980556
# 12  Regular customer  3.980556
# 13  Regular customer  3.980556
# 14  Regular customer  3.980556
#
# [15 rows x 23 columns]

# %%
## Deriving Columns with loc()
ords_prods_merge.loc[ords_prods_merge['avg_order'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_order'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...  prices _merge     busiest_day    busiest_days  \
# 0          0  ...     9.0   both  Regularly busy  Regularly days
# 1          1  ...     9.0   both  Regularly busy    Slowest days
# 2          1  ...     9.0   both  Regularly busy    Slowest days
# 3          1  ...     9.0   both      Least busy    Slowest days
# 4          1  ...     9.0   both      Least busy    Slowest days
#
#    busiest_period_of_day    price_range_loc max_order  loyalty_flag avg_order  \
# 0         Average orders  Mid-range product        10  New customer  6.367797
# 1         Average orders  Mid-range product        10  New customer  6.367797
# 2            Most orders  Mid-range product        10  New customer  6.367797
# 3         Average orders  Mid-range product        10  New customer  6.367797
# 4            Most orders  Mid-range product        10  New customer  6.367797
#
#   spending_flag
# 0   Low spender
# 1   Low spender
# 2   Low spender
# 3   Low spender
# 4   Low spender
#
# [5 rows x 24 columns]

# %%
# Check the frequency

ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 24)

# %% [markdown]
# ### Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column

# %%
# Creating “median_prior_order” column using transform()
ords_prods_merge['median_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2539329        1    prior             1                  2
# 1    2398795        1    prior             2                  3
# 2     473747        1    prior             3                  3
# 3    2254736        1    prior             4                  4
# 4     431534        1    prior             5                  4
# 5    3367565        1    prior             6                  2
# 6     550135        1    prior             7                  1
# 7    3108588        1    prior             8                  1
# 8    2295261        1    prior             9                  1
# 9    2550362        1    prior            10                  4
# 10   2968173       15    prior            15                  1
# 11   1870022       15    prior            17                  2
# 12   1911383       15    prior            18                  2
# 13   2715276       15    prior            21                  1
# 14    487368       15    prior            22                  1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
#
#     reordered  ...  _merge     busiest_day    busiest_days  \
# 0           0  ...    both  Regularly busy  Regularly days
# 1           1  ...    both  Regularly busy    Slowest days
# 2           1  ...    both  Regularly busy    Slowest days
# 3           1  ...    both      Least busy    Slowest days
# 4           1  ...    both      Least busy    Slowest days
# 5           1  ...    both  Regularly busy  Regularly days
# 6           1  ...    both  Regularly busy    Busiest days
# 7           1  ...    both  Regularly busy    Busiest days
# 8           1  ...    both  Regularly busy    Busiest days
# 9           1  ...    both      Least busy    Slowest days
# 10          0  ...    both  Regularly busy    Busiest days
# 11          1  ...    both  Regularly busy  Regularly days
# 12          1  ...    both  Regularly busy  Regularly days
# 13          1  ...    both  Regularly busy    Busiest days
# 14          1  ...    both  Regularly busy    Busiest days
#
#     busiest_period_of_day    price_range_loc max_order      loyalty_flag  \
# 0          Average orders  Mid-range product        10      New customer
# 1          Average orders  Mid-range product        10      New customer
# 2             Most orders  Mid-range product        10      New customer
# 3          Average orders  Mid-range product        10      New customer
# 4             Most orders  Mid-range product        10      New customer
# 5          Average orders  Mid-range product        10      New customer
# 6             Most orders  Mid-range product        10      New customer
# 7             Most orders  Mid-range product        10      New customer
# 8             Most orders  Mid-range product        10      New customer
# 9          Average orders  Mid-range product        10      New customer
# 10            Most orders  Mid-range product        22  Regular customer
# 11            Most orders  Mid-range product        22  Regular customer
# 12            Most orders  Mid-range product        22  Regular customer
# 13            Most orders  Mid-range product        22  Regular customer
# 14            Most orders  Mid-range product        22  Regular customer
#
#    avg_order spending_flag median_prior_order
# 0   6.367797   Low spender               20.5
# 1   6.367797   Low spender               20.5
# 2   6.367797   Low spender               20.5
# 3   6.367797   Low spender               20.5
# 4   6.367797   Low spender               20.5
# 5   6.367797   Low spender               20.5
# 6   6.367797   Low spender               20.5
# 7   6.367797   Low spender               20.5
# 8   6.367797   Low spender               20.5
# 9   6.367797   Low spender               20.5
# 10  3.980556   Low spender               10.0
# 11  3.980556   Low spender               10.0
# 12  3.980556   Low spender               10.0
# 13  3.980556   Low spender               10.0
# 14  3.980556   Low spender               10.0
#
# [15 rows x 25 columns]

# %%
## Deriving Columns with loc()
ords_prods_merge.loc[ords_prods_merge['median_prior_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_prior_order'] > 10) & (ords_prods_merge['median_prior_order']<=20), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_prior_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...     busiest_day    busiest_days  busiest_period_of_day  \
# 0          0  ...  Regularly busy  Regularly days         Average orders
# 1          1  ...  Regularly busy    Slowest days         Average orders
# 2          1  ...  Regularly busy    Slowest days            Most orders
# 3          1  ...      Least busy    Slowest days         Average orders
# 4          1  ...      Least busy    Slowest days            Most orders
#
#      price_range_loc  max_order  loyalty_flag avg_order spending_flag  \
# 0  Mid-range product         10  New customer  6.367797   Low spender
# 1  Mid-range product         10  New customer  6.367797   Low spender
# 2  Mid-range product         10  New customer  6.367797   Low spender
# 3  Mid-range product         10  New customer  6.367797   Low spender
# 4  Mid-range product         10  New customer  6.367797   Low spender
#
#   median_prior_order   order_frequency_flag
# 0               20.5  Non-frequent customer
# 1               20.5  Non-frequent customer
# 2               20.5  Non-frequent customer
# 3               20.5  Non-frequent customer
# 4               20.5  Non-frequent customer
#
# [5 rows x 26 columns]

# %%
# Check the frequency

ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %%
# Export Data
ords_prods_merge.to_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged_aggregated.pkl'))
